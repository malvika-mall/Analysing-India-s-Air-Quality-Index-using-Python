# %% [markdown]
# # 6.1 AQI Importing libraries and Python data types
#
# #This Script contains the following:
#
# #1 Importing Libraries
#
# #2 Project folder path string created and used to import “city_day.csv in dataframe;
#
# #3 Descriptive Analysis of dataframe;
#
# #4 Checking for missing values;
#
# #5 Analyzing Proportion of missing values in each column with Bar chart;
#
# #6 Subsetting data in relevant groups;
#
# #7 Exporting prepared data.

# %% [markdown]
# # 01 Importing Libraries

# %%
# Importing necessary libraries to conduct our analysis
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
#Reading the dataset into object 'df' using pandas:
path=r'C:\Users\User01\Analysing India Air Quality Data'
df_city= pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'city_day.csv'), index_col = False)
df_stations = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'station_day.csv'), index_col = False)
stations = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'stations.csv'), index_col = False)

# %%
df_city.shape
# Out:
# (29531, 16)

# %%
df_city.head()
# Out:
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
df_city.head(20)
# Out:
#          City        Date  PM2.5  PM10      NO    NO2     NOx  NH3      CO  \
# 0   Ahmedabad  2015-01-01    NaN   NaN    0.92  18.22   17.15  NaN    0.92
# 1   Ahmedabad  2015-01-02    NaN   NaN    0.97  15.69   16.46  NaN    0.97
# 2   Ahmedabad  2015-01-03    NaN   NaN   17.40  19.30   29.70  NaN   17.40
# 3   Ahmedabad  2015-01-04    NaN   NaN    1.70  18.48   17.97  NaN    1.70
# 4   Ahmedabad  2015-01-05    NaN   NaN   22.10  21.42   37.76  NaN   22.10
# 5   Ahmedabad  2015-01-06    NaN   NaN   45.41  38.48   81.50  NaN   45.41
# 6   Ahmedabad  2015-01-07    NaN   NaN  112.16  40.62  130.77  NaN  112.16
# 7   Ahmedabad  2015-01-08    NaN   NaN   80.87  36.74   96.75  NaN   80.87
# 8   Ahmedabad  2015-01-09    NaN   NaN   29.16  31.00   48.00  NaN   29.16
# 9   Ahmedabad  2015-01-10    NaN   NaN     NaN   7.04    0.00  NaN     NaN
# 10  Ahmedabad  2015-01-11    NaN   NaN  132.07  55.80   24.53  NaN  132.07
# ...

# %%
df_city.tail(35)
# Out:
#                 City        Date  PM2.5    PM10     NO    NO2    NOx    NH3  \
# 29496  Visakhapatnam  2020-05-28  26.94  102.00   1.63  20.67  12.23   8.67
# 29497  Visakhapatnam  2020-05-29  16.71   62.53   2.60  23.89  13.61  10.62
# 29498  Visakhapatnam  2020-05-30  28.10   84.80   7.43  50.99  27.93   9.21
# 29499  Visakhapatnam  2020-05-31  21.22   79.53   2.38  24.88  14.92  11.03
# 29500  Visakhapatnam  2020-06-01  15.68   81.88   1.91  20.61  12.15   8.25
# 29501  Visakhapatnam  2020-06-02   9.91   43.30   2.81  19.91  12.60   9.16
# 29502  Visakhapatnam  2020-06-03  17.94  102.58   5.60  30.32  20.59   9.49
# 29503  Visakhapatnam  2020-06-04  19.14   77.06   4.12  35.57  22.18   8.82
# 29504  Visakhapatnam  2020-06-05  29.71  112.53   2.98  44.77  24.69  10.51
# 29505  Visakhapatnam  2020-06-06  21.66   74.97   3.38  38.42  22.56   8.63
# 29506  Visakhapatnam  2020-06-07  29.69  101.97   2.84  35.51  20.66   9.85
# ...

# %%
#getting information about the columns in our dataset
df_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
#converting column Date into DateTime format
df_city['Date']=pd.to_datetime(df_city['Date'])

# %%
# review statistics of data
df_city.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# ...

# %%
# finding missing values
df_city.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
df_stations.head()
# Out:
#   StationId        Date  PM2.5    PM10    NO    NO2    NOx    NH3    CO  \
# 0     AP001  2017-11-24  71.36  115.75  1.75  20.65  12.40  12.19  0.10
# 1     AP001  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72  0.12
# 2     AP001  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28  0.14
# 3     AP001  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91  0.11
# 4     AP001  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42  0.09
#
#      SO2      O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 0  10.76  109.26     0.17     5.92    0.10    NaN        NaN
# 1  15.24  127.09     0.20     6.50    0.06  184.0   Moderate
# 2  26.96  117.44     0.22     7.95    0.08  197.0   Moderate
# 3  33.59  111.81     0.29     7.63    0.12  198.0   Moderate
# 4  19.00  138.18     0.17     5.02    0.07  188.0   Moderate

# %%
print(df_stations.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108035 entries, 0 to 108034
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   StationId   108035 non-null  object
#  1   Date        108035 non-null  object
#  2   PM2.5       86410 non-null   float64
#  3   PM10        65329 non-null   float64
#  4   NO          90929 non-null   float64
#  5   NO2         91488 non-null   float64
#  6   NOx         92535 non-null   float64
#  7   NH3         59930 non-null   float64
#  8   CO          95037 non-null   float64
#  9   SO2         82831 non-null   float64
#  10  O3          82467 non-null   float64
#  11  Benzene     76580 non-null   float64
#  12  Toluene     69333 non-null   float64
#  13  Xylene      22898 non-null   float64
#  14  AQI         87025 non-null   float64
#  15  AQI_Bucket  87025 non-null   object
# dtypes: float64(13), object(3)
# memory usage: 13.2+ MB
# None

# %%
stations.head()
# Out:
#   StationId                                     StationName  \
# 0     AP001                  Secretariat, Amaravati - APPCB
# 1     AP002  Anand Kala Kshetram, Rajamahendravaram - APPCB
# 2     AP003                      Tirumala, Tirupati - APPCB
# 3     AP004                 PWD Grounds, Vijayawada - APPCB
# 4     AP005          GVM Corporation, Visakhapatnam - APPCB
#
#                 City           State  Status
# 0          Amaravati  Andhra Pradesh  Active
# 1  Rajamahendravaram  Andhra Pradesh     NaN
# 2           Tirupati  Andhra Pradesh     NaN
# 3         Vijayawada  Andhra Pradesh     NaN
# 4      Visakhapatnam  Andhra Pradesh  Active

# %%
print(stations.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   StationId    230 non-null    object
#  1   StationName  230 non-null    object
#  2   City         230 non-null    object
#  3   State        230 non-null    object
#  4   Status       133 non-null    object
# dtypes: object(5)
# memory usage: 9.1+ KB
# None

# %% [markdown]
# # 'df_city' gives us city-level data of pollutants and their AQI levels. 'df_stations' gives us updates from different weather stations and 'stations' gives info about these stations.
#
# It would make sense to merge 'df_stations' with 'stations'.

# %%
df_stations = pd.merge(df_stations,stations,how = 'left')
df_stations.head()
# Out:
#   StationId        Date  PM2.5    PM10    NO    NO2    NOx    NH3    CO  \
# 0     AP001  2017-11-24  71.36  115.75  1.75  20.65  12.40  12.19  0.10
# 1     AP001  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72  0.12
# 2     AP001  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28  0.14
# 3     AP001  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91  0.11
# 4     AP001  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42  0.09
#
#      SO2      O3  Benzene  Toluene  Xylene    AQI AQI_Bucket  \
# 0  10.76  109.26     0.17     5.92    0.10    NaN        NaN
# 1  15.24  127.09     0.20     6.50    0.06  184.0   Moderate
# 2  26.96  117.44     0.22     7.95    0.08  197.0   Moderate
# 3  33.59  111.81     0.29     7.63    0.12  198.0   Moderate
# 4  19.00  138.18     0.17     5.02    0.07  188.0   Moderate
#
#                       StationName       City           State  Status
# 0  Secretariat, Amaravati - APPCB  Amaravati  Andhra Pradesh  Active
# ...

# %%
city_states = {'Ahmedabad': 'Gujarat',
 'Aizawl': 'Mizoram',
 'Amaravati': 'Andhra Pradesh',
 'Amritsar': 'Punjab',
 'Bengaluru': 'Karnataka',
 'Bhopal': 'Madhya Pradesh',
 'Brajrajnagar': 'Orissa',
 'Chandigarh': 'Chandigarh',
 'Chennai': 'Tamil Nadu',
 'Coimbatore': 'Tamil Nadu',
 'Delhi': 'Delhi',
 'Ernakulam': 'Kerala',
 'Gurugram': 'Haryana',
 'Guwahati': 'Assam',
 'Hyderabad': 'Andhra Pradesh',
 'Jaipur': 'Rajasthan',
 'Jorapokhar': 'Jharkhand',
 'Kochi': 'Kerala',
 'Kolkata': 'West Bengal',
 'Lucknow': 'Uttar Pradesh',
 'Mumbai': 'Maharashtra',
 'Patna': 'Bihar',
 'Shillong': 'Meghalaya',
 'Talcher': 'Orissa',
 'Thiruvananthapuram': 'Kerala',
 'Visakhapatnam': 'Andhra Pradesh'}

# %%
#adding states and state ID to df_city
df_city['State'] = df_city['City'].apply(lambda x: city_states[x])

# %% [markdown]
# # 05 Analyzing Proportion of missing values in each column with Bar chart.

# %%
import missingno as msno
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#finding the proportion of missing values in each column
missing=pd.DataFrame(df_city.isna().sum()/len(df_city))
missing.columns=['Proportion']
print(missing.sort_values(by='Proportion', ascending=False))

#plotting the number of non-null values in each column
msno.bar(df_city)
# Out:
#             Proportion
# Xylene        0.613220
# PM10          0.377231
# NH3           0.349734
# Toluene       0.272290
# Benzene       0.190410
# AQI           0.158511
# AQI_Bucket    0.158511
# PM2.5         0.155701
# NOx           0.141715
# O3            0.136196
# SO2           0.130507
# NO2           0.121398
# NO            0.121296
# CO            0.069723
# City          0.000000
# Date          0.000000
# State         0.000000
# <Axes: >

# %% [markdown]
# # As the above bar graph clearly indicates that PM10 and Xylene have high proportion of missing values. This might be due to manual inconsistencies or human negligence while recording or absence of enough stations in the city.

# %%
#filling missing values with zero 
df_city.fillna(0,inplace=True)

# %% [markdown]
# # The missing values can also be imputed by way of mean but i choose to replace it with zero to avoid skewing of data.

# %%
#finding the proportion of missing values in each column stations
import missingno as msno
missing=pd.DataFrame(df_stations.isna().sum()/len(df_stations))
missing.columns=['Proportion']
print(missing.sort_values(by='Proportion', ascending=False))

#plotting the number of non-null values in each column
msno.bar(df_stations)
# Out:
#              Proportion
# Xylene         0.788050
# NH3            0.445272
# PM10           0.395298
# Toluene        0.358236
# Benzene        0.291156
# O3             0.236664
# SO2            0.233295
# PM2.5          0.200167
# AQI            0.194474
# AQI_Bucket     0.194474
# NO             0.158338
# NO2            0.153163
# NOx            0.143472
# CO             0.120313
# Status         0.002999
# Date           0.000000
# StationName    0.000000
# City           0.000000
# State          0.000000
# StationId      0.000000
# <Axes: >

# %%
#filling missing values with zero 
df_stations['AQI'].fillna(0,inplace=True)
df_stations['AQI_Bucket'].fillna('Not Provided',inplace = True)

# %%
#extracting year and month for each record
df_city['year'] = pd.DatetimeIndex(df_city['Date']).year
df_city['month'] = pd.DatetimeIndex(df_city['Date']).month

# %%
#subsetting data in relevan group
df_city['PM']=df_city['PM2.5'] + df_city['PM10']

# %%
#subsettinubbing nitrogen oxides
df_city['Nitric']=df_city['NO'] + df_city['NO2']+ df_city['NOx']

# %%
# subsetting Benzene, toluene and Xylene together
df_city['BTX']=df_city['Benzene'] + df_city['Toluene']+ df_city['Xylene']

# %%
#grouping pollutant levels in every city by year and month
cities_group_ym=df_city.groupby(['State','City','year','month'])[['PM','Nitric','CO','NH3','O3','SO2','BTX','AQI']].mean()

cities_group_ym=cities_group_ym.reset_index(['City','year','month'])
cities_group_ym.head()
# Out:
#                      City  year  month          PM     Nitric        CO  \
# State
# Andhra Pradesh  Amaravati  2017     11  194.958571  43.172857  0.120000
# Andhra Pradesh  Amaravati  2017     12  229.464516  70.963548  0.151935
# Andhra Pradesh  Amaravati  2018      1  215.278387  73.489032  0.069355
# Andhra Pradesh  Amaravati  2018      2  155.282143  45.791786  0.575000
# Andhra Pradesh  Amaravati  2018      3  117.172581  35.543226  0.706774
#
#                       NH3          O3        SO2       BTX         AQI
# State
# Andhra Pradesh  11.531429  118.801429  18.595714  6.177143  157.857143
# Andhra Pradesh  17.501290   77.179355  14.312903  4.726774  194.129032
# Andhra Pradesh  21.212903   68.874194  14.839355  6.280645  172.451613
# Andhra Pradesh  17.724643   28.923571  11.025714  3.023929  107.035714
# Andhra Pradesh  13.217097   22.076452  10.769355  2.160000   77.516129

# %%
# Exporting prepared data
cities_group_ym.to_csv(os.path.join(path, '02 Data','Prepared Data', 'city_checked.csv'))

# %%
# Exporting prepared data
df_stations.to_csv(os.path.join(path, '02 Data','Prepared Data', 'stations_checked.csv'))
